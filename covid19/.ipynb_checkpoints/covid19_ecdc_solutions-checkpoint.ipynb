# %% [markdown]
# ### Analysis of number of covid19 cases using ECDC data

# %% [markdown]
# you can get data from:
# https://opendata.ecdc.europa.eu/covid19/casedistribution/csv

# %%
# first read data into a dataframe
import pandas as pd
data=pd.read_csv("covid19_ecdc_28_07_20.csv")
data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  27/07/2020   27      7  2020    106      10             Afghanistan    AF
# 1  26/07/2020   26      7  2020    121      13             Afghanistan    AF
# 2  25/07/2020   25      7  2020    108      35             Afghanistan    AF
# 3  24/07/2020   24      7  2020     13       0             Afghanistan    AF
# 4  23/07/2020   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           4.763187
# 1                                           4.484546
# 2                                           4.389913
# 3                                           5.309955
# 4                                           5.946098

# %%
# create datetime objects for the "dateRep" column
data.dateRep=pd.to_datetime(data.dateRep,format="%d/%m/%Y")

# %%
# reshape the data: Show countries in rows, dates in columns and values should be cases
confirmed_by_country=data.pivot(index="countriesAndTerritories",columns="dateRep",values="cases")
confirmed_by_country.head()
# Out:
# dateRep                  2019-12-31  2020-01-01  2020-01-02  2020-01-03  \
# countriesAndTerritories
# Afghanistan                     0.0         0.0         0.0         0.0
# Albania                         NaN         NaN         NaN         NaN
# Algeria                         0.0         0.0         0.0         0.0
# Andorra                         NaN         NaN         NaN         NaN
# Angola                          NaN         NaN         NaN         NaN
#
# dateRep                  2020-01-04  2020-01-05  2020-01-06  2020-01-07  \
# countriesAndTerritories
# Afghanistan                     0.0         0.0         0.0         0.0
# Albania                         NaN         NaN         NaN         NaN
# Algeria                         0.0         0.0         0.0         0.0
# Andorra                         NaN         NaN         NaN         NaN
# Angola                          NaN         NaN         NaN         NaN
#
# dateRep                  2020-01-08  2020-01-09  ...  2020-07-18  2020-07-19  \
# countriesAndTerritories                          ...
# Afghanistan                     0.0         0.0  ...       219.0        12.0
# Albania                         NaN         NaN  ...        55.0       102.0
# Algeria                         0.0         0.0  ...       593.0       601.0
# Andorra                         NaN         NaN  ...         3.0         0.0
# Angola                          NaN         NaN  ...        31.0        49.0
#
# dateRep                  2020-07-20  2020-07-21  2020-07-22  2020-07-23  \
# countriesAndTerritories
# Afghanistan                   174.0       140.0       112.0       188.0
# Albania                        82.0        81.0       119.0        68.0
# Algeria                       535.0       607.0       587.0       594.0
# Andorra                         0.0         4.0         0.0         5.0
# Angola                         18.0        44.0         0.0        30.0
#
# dateRep                  2020-07-24  2020-07-25  2020-07-26  2020-07-27
# countriesAndTerritories
# Afghanistan                    13.0       108.0       121.0       106.0
# Albania                       108.0       104.0        67.0       126.0
# Algeria                       612.0       675.0       605.0       593.0
# Andorra                         0.0         0.0         8.0         0.0
# Angola                         33.0        39.0        29.0         0.0
#
# [5 rows x 210 columns]

# %%
# calculate rolling average of cases for 7-day windows
confirmed_7day_mean=confirmed_by_country.rolling(7,axis=1,min_periods=1).mean()

# %%
confirmed_7day_mean
# Out:
# dateRep                  2019-12-31  2020-01-01  2020-01-02  2020-01-03  \
# countriesAndTerritories
# Afghanistan                     0.0         0.0         0.0         0.0
# Albania                         NaN         NaN         NaN         NaN
# Algeria                         0.0         0.0         0.0         0.0
# Andorra                         NaN         NaN         NaN         NaN
# Angola                          NaN         NaN         NaN         NaN
# ...                             ...         ...         ...         ...
# Vietnam                         0.0         0.0         0.0         0.0
# Western_Sahara                  NaN         NaN         NaN         NaN
# Yemen                           NaN         NaN         NaN         NaN
# Zambia                          NaN         NaN         NaN         NaN
# Zimbabwe                        NaN         NaN         NaN         NaN
#
# dateRep                  2020-01-04  2020-01-05  2020-01-06  2020-01-07  \
# countriesAndTerritories
# Afghanistan                     0.0         0.0         0.0         0.0
# Albania                         NaN         NaN         NaN         NaN
# Algeria                         0.0         0.0         0.0         0.0
# Andorra                         NaN         NaN         NaN         NaN
# Angola                          NaN         NaN         NaN         NaN
# ...                             ...         ...         ...         ...
# Vietnam                         0.0         0.0         0.0         0.0
# Western_Sahara                  NaN         NaN         NaN         NaN
# Yemen                           NaN         NaN         NaN         NaN
# Zambia                          NaN         NaN         NaN         NaN
# Zimbabwe                        NaN         NaN         NaN         NaN
#
# dateRep                  2020-01-08  2020-01-09  ...  2020-07-18  2020-07-19  \
# countriesAndTerritories                          ...
# Afghanistan                     0.0         0.0  ...  131.857143  121.428571
# Albania                         NaN         NaN  ...   89.714286   91.000000
# Algeria                         0.0         0.0  ...  591.428571  548.142857
# Andorra                         NaN         NaN  ...    3.571429    3.571429
# Angola                          NaN         NaN  ...   25.714286   29.142857
# ...                             ...         ...  ...         ...         ...
# Vietnam                         0.0         0.0  ...    0.428571    0.428571
# Western_Sahara                  NaN         NaN  ...   35.285714   35.285714
# Yemen                           NaN         NaN  ...   28.000000   27.428571
# Zambia                          NaN         NaN  ...  130.714286  155.000000
# Zimbabwe                        NaN         NaN  ...   68.285714   70.857143
#
# dateRep                  2020-07-20  2020-07-21  2020-07-22  2020-07-23  \
# countriesAndTerritories
# Afghanistan              146.285714  165.714286  141.000000  131.571429
# Albania                   90.857143   85.714286   89.000000   86.571429
# Algeria                  555.571429  571.714286  580.285714  586.000000
# Andorra                    3.571429    3.714286    3.285714    3.857143
# Angola                    28.428571   34.714286   32.000000   29.000000
# ...                             ...         ...         ...         ...
# Vietnam                    0.142857    0.000000    4.000000    5.000000
# Western_Sahara            35.285714    0.714286    0.000000    0.000000
# Yemen                     20.142857   17.285714   18.142857   16.285714
# Zambia                   155.000000  204.428571  149.000000  185.714286
# Zimbabwe                  89.428571   97.000000  112.285714  135.000000
#
# dateRep                  2020-07-24  2020-07-25  2020-07-26  2020-07-27
# countriesAndTerritories
# Afghanistan              122.571429  106.714286  122.285714  112.571429
# Albania                   87.857143   94.857143   89.857143   96.142857
# Algeria                  589.857143  601.571429  602.142857  610.428571
# Andorra                    1.714286    1.285714    2.428571    2.428571
# Angola                    29.285714   30.428571   27.571429   25.000000
# ...                             ...         ...         ...         ...
# Vietnam                    5.571429    6.000000    6.000000    6.714286
# Western_Sahara             0.000000    0.000000    0.000000    0.000000
# Yemen                     14.571429   11.142857   13.285714   10.714286
# Zambia                   185.714286  149.428571  192.571429  214.428571
# Zimbabwe                 108.857143  125.142857  136.571429  128.714286
#
# [210 rows x 210 columns]

# %%
# select countries whose number of cases to be plotted
selected_countries=["United_States_of_America","Brazil","Italy","Germany","United_Kingdom","India","Russia","Turkey"]

# %%
# now get data for these countries
data_selected=confirmed_7day_mean.loc[selected_countries]

# %%
data_selected
# Out:
# dateRep                   2019-12-31  2020-01-01  2020-01-02  2020-01-03  \
# countriesAndTerritories
# United_States_of_America         0.0         0.0         0.0         0.0
# Brazil                           0.0         0.0         0.0         0.0
# Italy                            0.0         0.0         0.0         0.0
# Germany                          0.0         0.0         0.0         0.0
# United_Kingdom                   0.0         0.0         0.0         0.0
# India                            0.0         0.0         0.0         0.0
# Russia                           0.0         0.0         0.0         0.0
# Turkey                           NaN         NaN         NaN         NaN
#
# dateRep                   2020-01-04  2020-01-05  2020-01-06  2020-01-07  \
# countriesAndTerritories
# United_States_of_America         0.0         0.0         0.0         0.0
# Brazil                           0.0         0.0         0.0         0.0
# Italy                            0.0         0.0         0.0         0.0
# Germany                          0.0         0.0         0.0         0.0
# United_Kingdom                   0.0         0.0         0.0         0.0
# India                            0.0         0.0         0.0         0.0
# Russia                           0.0         0.0         0.0         0.0
# Turkey                           NaN         NaN         NaN         NaN
#
# dateRep                   2020-01-08  2020-01-09  ...    2020-07-18  \
# countriesAndTerritories                           ...
# United_States_of_America         0.0         0.0  ...  66154.571429
# Brazil                           0.0         0.0  ...  35071.571429
# Italy                            0.0         0.0  ...    189.714286
# Germany                          0.0         0.0  ...    402.285714
# United_Kingdom                   0.0         0.0  ...    729.428571
# India                            0.0         0.0  ...  31114.285714
# Russia                           0.0         0.0  ...   7357.285714
# Turkey                           NaN         NaN  ...    976.285714
#
# dateRep                     2020-07-19    2020-07-20    2020-07-21  \
# countriesAndTerritories
# United_States_of_America  66254.285714  66902.571429  66707.714286
# Brazil                    33572.857143  33386.857143  33382.714286
# Italy                       198.428571    196.142857    199.142857
# Germany                     395.714286    408.571429    483.142857
# United_Kingdom              730.428571    741.285714    748.428571
# India                     32580.714286  34255.571429  35491.285714
# Russia                     7285.571429   6340.571429   6255.285714
# Turkey                      962.285714    949.714286    938.714286
#
# dateRep                     2020-07-22    2020-07-23    2020-07-24  \
# countriesAndTerritories
# United_States_of_America  67212.000000  67373.571429  65411.571429
# Brazil                    33261.428571  37252.285714  39332.000000
# Italy                       201.142857    218.000000    228.857143
# Germany                     439.000000    444.000000    477.142857
# United_Kingdom              634.857143    638.000000    656.285714
# India                     36676.285714  38537.000000  40587.571429
# Russia                     6197.285714   6117.285714   6034.428571
# Turkey                      929.571429    923.142857    920.285714
#
# dateRep                     2020-07-25    2020-07-26    2020-07-27
# countriesAndTerritories
# United_States_of_America  66402.000000  66651.857143  65822.857143
# Brazil                    42434.000000  45664.714286  45814.571429
# Italy                       231.857143    235.428571    240.571429
# Germany                     513.142857    527.857143    540.857143
# United_Kingdom              667.857143    659.285714    662.000000
# India                     42592.142857  43986.285714  45344.285714
# Russia                     5058.857143   5024.857143   5848.428571
# Turkey                      921.857143    922.285714    922.714286
#
# [8 rows x 210 columns]

# %%
# plot confirmed cases vs time
data_selected.T.plot()

# %% [markdown]
# ### Let's plot cumulative confirmed case number

# %%
cumulative_cases=data_selected.cumsum(axis="columns")

# %%
cumulative_cases.T.plot()

# %%
data.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           4.763187
# 1                                           4.484546
# 2                                           4.389913
# 3                                           5.309955
# 4                                           5.946098

# %% [markdown]
# ### How many countries are here?

# %%
# get the number of unique countriesAndTerritories
data.countriesAndTerritories.nunique()
# Out:
# 210

# %%
# get the number of countryterritoryCode
data.countryterritoryCode.nunique()
# Out:
# 209

# %%
# drop duplicates for countriesAndTerritories and countryterritoryCode columns
no_duplicate=data.drop_duplicates(subset=["countriesAndTerritories","countryterritoryCode"])

# %%
no_duplicate
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-07-27   27      7  2020    106      10             Afghanistan
# 200   2020-07-27   27      7  2020    126       4                 Albania
# 341   2020-07-27   27      7  2020    593       9                 Algeria
# 546   2020-07-27   27      7  2020      0       0                 Andorra
# 682   2020-07-27   27      7  2020      0       0                  Angola
# ...          ...  ...    ...   ...    ...     ...                     ...
# 31764 2020-07-27   27      7  2020      5       0                 Vietnam
# 31970 2020-07-27   27      7  2020      0       0          Western_Sahara
# 32063 2020-07-27   27      7  2020      7       5                   Yemen
# 32172 2020-07-27   27      7  2020    153       9                  Zambia
# 32303 2020-07-27   27      7  2020     78       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 0        AF                  AFG   38041757.0         Asia
# 200      AL                  ALB    2862427.0       Europe
# 341      DZ                  DZA   43053054.0       Africa
# 546      AD                  AND      76177.0       Europe
# 682      AO                  AGO   31825299.0       Africa
# ...     ...                  ...          ...          ...
# 31764    VN                  VNM   96462108.0         Asia
# 31970    EH                  ESH     582458.0       Africa
# 32063    YE                  YEM   29161922.0         Asia
# 32172    ZM                  ZMB   17861034.0       Africa
# 32303    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                               4.763187
# 200                                            45.730424
# 341                                            18.958005
# 546                                            55.134752
# 682                                             1.175166
# ...                                                  ...
# 31764                                           0.049760
# 31970                                          42.406491
# 32063                                           0.740692
# 32172                                          14.478445
# 32303                                          10.426430
#
# [210 rows x 12 columns]

# %% [markdown]
# ### select only two columns:  countriesAndTerritories and countryterritoryCode

# %%
no_duplicate_small=no_duplicate[["countriesAndTerritories","countryterritoryCode"]]

# %%
no_duplicate_small
# Out:
#       countriesAndTerritories countryterritoryCode
# 0                 Afghanistan                  AFG
# 200                   Albania                  ALB
# 341                   Algeria                  DZA
# 546                   Andorra                  AND
# 682                    Angola                  AGO
# ...                       ...                  ...
# 31764                 Vietnam                  VNM
# 31970          Western_Sahara                  ESH
# 32063                   Yemen                  YEM
# 32172                  Zambia                  ZMB
# 32303                Zimbabwe                  ZWE
#
# [210 rows x 2 columns]

# %% [markdown]
# - let's check if one code is used more than once

# %%
no_duplicate_small.countryterritoryCode.value_counts(dropna=False)
# Out:
# CAN    1
# UGA    1
# BGD    1
# ROU    1
# CMR    1
#       ..
# LBN    1
# DOM    1
# BIH    1
# MKD    1
# NaN    1
# Name: countryterritoryCode, Length: 210, dtype: int64

# %% [markdown]
# - It seems one country does not have a code, let's find that country
# - we need to find the row where we see countryterritoryCode as NaN

# %%
find_na=data.countryterritoryCode.isna()

# %%
find_na
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32427    False
# 32428    False
# 32429    False
# 32430    False
# 32431    False
# Name: countryterritoryCode, Length: 32432, dtype: bool

# %%
no_duplicate_small[find_na]
# Out:
# /Users/sefer_imac/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                          countriesAndTerritories countryterritoryCode
# 5755  Cases_on_an_international_conveyance_Japan                  NaN

# %% [markdown]
# ### Let's play with columns

# %%
data.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           4.763187
# 1                                           4.484546
# 2                                           4.389913
# 3                                           5.309955
# 4                                           5.946098

# %%
# delete popData2019 and Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 columns
data_new=data.drop(labels=["popData2019","Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"],axis=1)

# %%
data_new.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode continentExp
# 0                  AFG         Asia
# 1                  AFG         Asia
# 2                  AFG         Asia
# 3                  AFG         Asia
# 4                  AFG         Asia

# %% [markdown]
# ### read population data using world_population.csv file

# %%
pop=pd.read_csv("world_population.csv",skiprows=4)

# %%
pop.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# 0    102560.0    103159.0    103774.0    104341.0    104872.0    105366.0
# 1  31161376.0  32269589.0  33370794.0  34413603.0  35383128.0  36296400.0
# 2  25107931.0  26015780.0  26941779.0  27884381.0  28842484.0  29816748.0
# 3   2900401.0   2895092.0   2889104.0   2880703.0   2876101.0   2873457.0
# 4     82427.0     80774.0     79213.0     78011.0     77297.0     77001.0
#
#          2018        2019  Unnamed: 64
# 0    105845.0    106314.0          NaN
# 1  37172386.0  38041754.0          NaN
# 2  30809762.0  31825295.0          NaN
# 3   2866376.0   2854191.0          NaN
# 4     77006.0     77142.0          NaN
#
# [5 rows x 65 columns]

# %%
# extract only Country Name and 2019 columns
pop_19=pop[["Country Name","2019"]]

# %%
pop_19
# Out:
#      Country Name        2019
# 0           Aruba    106314.0
# 1     Afghanistan  38041754.0
# 2          Angola  31825295.0
# 3         Albania   2854191.0
# 4         Andorra     77142.0
# ..            ...         ...
# 259        Kosovo   1794248.0
# 260   Yemen, Rep.  29161922.0
# 261  South Africa  58558270.0
# 262        Zambia  17861030.0
# 263      Zimbabwe  14645468.0
#
# [264 rows x 2 columns]

# %%
data_new.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode continentExp
# 0                  AFG         Asia
# 1                  AFG         Asia
# 2                  AFG         Asia
# 3                  AFG         Asia
# 4                  AFG         Asia

# %%
# now add population information into data_new data frame
data_pop=pd.merge(data_new,pop_19,left_on="countriesAndTerritories",right_on="Country Name")

# %%
data_pop.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode continentExp Country Name        2019
# 0                  AFG         Asia  Afghanistan  38041754.0
# 1                  AFG         Asia  Afghanistan  38041754.0
# 2                  AFG         Asia  Afghanistan  38041754.0
# 3                  AFG         Asia  Afghanistan  38041754.0
# 4                  AFG         Asia  Afghanistan  38041754.0

# %%
# rename 2019 column as population
data_pop.rename({"2019":"population"},axis=1,inplace=True)

# %%
data_pop.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode continentExp Country Name  population
# 0                  AFG         Asia  Afghanistan  38041754.0
# 1                  AFG         Asia  Afghanistan  38041754.0
# 2                  AFG         Asia  Afghanistan  38041754.0
# 3                  AFG         Asia  Afghanistan  38041754.0
# 4                  AFG         Asia  Afghanistan  38041754.0

# %%
data.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-07-27   27      7  2020    106      10             Afghanistan    AF
# 1 2020-07-26   26      7  2020    121      13             Afghanistan    AF
# 2 2020-07-25   25      7  2020    108      35             Afghanistan    AF
# 3 2020-07-24   24      7  2020     13       0             Afghanistan    AF
# 4 2020-07-23   23      7  2020    188      21             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000        new
# 0                                           4.763187            2.786412
# 1                                           4.484546            5.967127
# 2                                           4.389913            8.806113
# 3                                           5.309955            9.147842
# 4                                           5.946098           14.089780
